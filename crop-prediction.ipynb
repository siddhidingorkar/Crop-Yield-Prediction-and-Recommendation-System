# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
crop_data=pd.read_csv("crop_production.csv")
crop_data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
crop_data = crop_data.dropna()
crop_data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
crop_data['Yield'] = (crop_data['Production'] / crop_data['Area'])
crop_data.head(10)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_20788\2128531304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crop_data['Yield'] = (crop_data['Production'] / crop_data['Area'])
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...

# %%
data = crop_data.drop(['State_Name'], axis = 1)

# %%
dummy = pd.get_dummies(data)
dummy
# Out:
#         Crop_Year      Area  Production      Yield  \
# 0            2000    1254.0      2000.0   1.594896
# 1            2000       2.0         1.0   0.500000
# 2            2000     102.0       321.0   3.147059
# 3            2000     176.0       641.0   3.642045
# 4            2000     720.0       165.0   0.229167
# ...           ...       ...         ...        ...
# 246086       2014     306.0       801.0   2.617647
# 246087       2014     627.0       463.0   0.738437
# 246088       2014     324.0     16250.0  50.154321
# 246089       2014  279151.0    597899.0   2.141848
# 246090       2014     175.0        88.0   0.502857
#
#         District_Name_24 PARAGANAS NORTH  District_Name_24 PARAGANAS SOUTH  \
# 0                                  False                             False
# 1                                  False                             False
# 2                                  False                             False
# ...

# %%
from sklearn.model_selection import train_test_split

x = dummy.drop(["Production","Yield"], axis=1)
y = dummy["Production"]

# Splitting data set - 25% test dataset and 75% 

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=5)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 11)
model.fit(x_train,y_train)
#pickle.dump(model, open('model.sav', 'wb'))
rf_predict = model.predict(x_test)
rf_predict
# Out:
# array([3894.89090909,  636.54545455, 2398.45454545, ...,  176.76363636,
#        9251.36363636,  100.        ])

# %%
model.score(x_test,y_test)
# Out:
# 0.9625100125139463

# %%
def predict_yield(user_input):
    # Convert user input to DataFrame
    user_df = pd.DataFrame([user_input])
    # Perform one-hot encoding
    user_dummy = pd.get_dummies(user_df)
    # Ensure the input columns match the trained model columns
    missing_cols = set(x_train.columns) - set(user_dummy.columns)
    for col in missing_cols:
        user_dummy[col] = 0
    user_dummy = user_dummy[x_train.columns]
    # Predict yield
    predicted_yield = model.predict(user_dummy)
    return predicted_yield[0]

# %%
#1st Crop Yeild Prediction 
def predict_yield_from_input():
    # Accept user input
    crop = input("Enter crop name: ")
    year = int(input("Enter year: "))
    season = input("Enter season: ")
    area = float(input("Enter area: "))
    production = float(input("Enter area: "))

    # Create user input dictionary
    user_input = {
        'Crop': crop,
        'Year': year,
        'Season': season,
        'Area': area
        'Production': production
    }

    # Predict yield
    predicted_yield = predict_yield(user_input)
    print("Predicted Yield:", predicted_yield)

# Call the function to predict yield based on user input
predict_yield_from_input()

# %%
# 2nd Crop Yeild Prediction
def predict_yield(user_input):
    # Convert user input to DataFrame
    user_df = pd.DataFrame([user_input])
    # Perform one-hot encoding
    user_dummy = pd.get_dummies(user_df)
    # Ensure the input columns match the trained model columns
    missing_cols = set(x_train.columns) - set(user_dummy.columns)
    for col in missing_cols:
        user_dummy[col] = 0
    user_dummy = user_dummy[x_train.columns]
    # Predict yield
    predicted_yield = model.predict(user_dummy)
    return predicted_yield[0]

# %%
def predict_yield_from_input():
    # Accept user input
    crop = input("Enter crop name: ")
    year = int(input("Enter year: "))
    season = input("Enter season: ")
    area = float(input("Enter area: "))

    # Create user input dictionary
    user_input = {
        'Crop': crop,
        'Year': year,
        'Season': season,
        'Area': area
    }

    # Predict yield
    predicted_yield = predict_yield(user_input)
    print("Predicted Yield: in kilograms per hectare ", predicted_yield)

# Call the function to predict yield based on user input
predict_yield_from_input()
# Out:
# Enter crop name:  Sweet potato
# Enter year:  2008
# Enter season:  Rabi
# Enter area:  4333
# C:\Users\siddh\AppData\Local\Temp\ipykernel_3936\1117342241.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_dummy[col] = 0
# C:\Users\siddh\AppData\Local\Temp\ipykernel_3936\1117342241.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   user_dummy[col] = 0
# ...

# %%
model = pickle.load(open('model.sav', 'rb'))
result = model.score(x_test, y_test)
print(result)
# Out:
# 0.9625100125139463

# %%
# 2nd Crop Yeild Prediction
def predict_yield(user_input):
    # Convert user input to DataFrame
    user_df = pd.DataFrame([user_input])
    # Perform one-hot encoding
    user_dummy = pd.get_dummies(user_df)
    # Ensure the input columns match the trained model columns
    missing_cols = set(x_train.columns) - set(user_dummy.columns)
    for col in missing_cols:
        user_dummy[col] = 0
    user_dummy = user_dummy[x_train.columns]
    # Predict yield
    predicted_yield = model.predict(user_dummy)
    return predicted_yield[0]

# %%
def predict_yield_from_input():
    # Accept user input
    crop = input("Enter crop name: ")
    year = int(input("Enter year: "))
    season = input("Enter season: ")
    area = float(input("Enter area: "))

    # Create user input dictionary
    user_input = {
        'Crop': crop,
        'Year': year,
        'Season': season,
        'Area': area
    }

    # Predict yield
    predicted_yield = predict_yield(user_input)
    print("Predicted Yield: in kilograms per hectare ", predicted_yield)

# Call the function to predict yield based on user input
predict_yield_from_input()
